# %%
import pandas as pd


df = pd.read_excel('NPI.xlsx')


HAV = 20  


df['NPI'] = (df['NO3'] - HAV) / HAV


df.to_excel('npi_results.xlsx', index=False)

print(df.head())
# Out:
#    Sl    NO3    NPI
# 0    1   1.0 -0.950
# 1    2  17.0 -0.150
# 2    3  36.0  0.800
# 3    4   5.0 -0.750
# 4    5   0.3 -0.985
