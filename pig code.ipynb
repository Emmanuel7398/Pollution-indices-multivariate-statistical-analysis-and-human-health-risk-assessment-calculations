# %%
import pandas as pd

# %%
df=pd.read_excel('water quality.xlsx')
df.head(84)
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
#     HCO3
# 0    325
# 1    336
# 2    310
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.pH,4,8.5)
df['Ow_pH']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
#     HCO3     Ow_pH
# 0    325  0.094118
# ...

# %%
def exmp(c, w=4, s=500):
    relw = w / 40
    return relw * (c / s)

df['Ow_TDS (m)'] = exmp(df['TDS (m)'])

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
#     HCO3     Ow_pH  Ow_TDS (m)
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.Ca,2,75)
df['Ow_Ca']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
#     HCO3     Ow_pH  Ow_TDS (m)     Ow_Ca
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.Mg,2,50)
df['Ow_Mg']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.Na,4,200)
df['Ow_Na']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.K,2,12)
df['Ow_K']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.HCO3,3,600)
df['Ow_HCO3']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.Cl,4,250)
df['Ow_Cl']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...     F  HCO3  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...  4.00   325
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...  1.40   336
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...  1.20   310
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...  2.30   165
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...  6.40   122
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...   ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...  3.80   310
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...  0.70   200
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...  4.30    85
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...  4.30   421
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...  0.01   494
#
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.SO4,5,250)
df['Ow_SO4']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...  HCO3  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...   325
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...   336
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...   310
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...   165
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...   122
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...   310
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...   200
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...    85
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...   421
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...   494
#
#        Ow_pH  Ow_TDS (m)     Ow_Ca  Ow_Mg   Ow_Na      Ow_K   Ow_HCO3   Ow_Cl  \
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.NO3,5,45)
df['Ow_NO3']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...     Ow_pH  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...  0.094118
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...  0.080000
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...  0.080000
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...  0.084706
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...  0.100000
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...       ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...  0.092941
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...  0.071765
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...  0.094118
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...  0.094118
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...  0.070588
#
# ...

# %%
def exmp(c,w,s):
    relw=w/40
    pig=relw*(c/s)
    return pig
x=exmp (df.F,5,1.5)
df['Ow_F']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...  Ow_TDS (m)  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...      0.0940
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...      0.1012
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...      0.1180
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...      0.0430
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...      0.1244
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...         ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...      0.1392
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...      0.0936
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...      0.0520
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...      0.1158
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...      0.1446
#
# ...

# %%
df.drop(['EC','TH'],axis=1,inplace=True)

# %%
df
# Out:
#     Sl no.   pH  TDS (m)   Na     K  Ca  Mg  SO4   NO3   Cl  ...  Ow_TDS (m)  \
# 0        1  8.0      470   43   3.0  42  24    6   1.0   30  ...      0.0940
# 1        2  6.8      506   31   3.0  48  37    4  17.0   55  ...      0.1012
# 2        3  6.8      590   55   6.0  32  46   17  36.0   92  ...      0.1180
# 3        4  7.2      215   16   4.0  20  19    6   5.0    2  ...      0.0430
# 4        5  8.5      622  183   6.0  12   7   43   0.3  250  ...      0.1244
# ..     ...  ...      ...  ...   ...  ..  ..  ...   ...  ...  ...         ...
# 78      79  7.9      696  116   6.0  42  26   40   5.0  150  ...      0.1392
# 79      80  6.1      468  120   3.0  60  45   20   2.0   30  ...      0.0936
# 80      81  8.0      260   30  17.0  24  10   20   6.0   70  ...      0.0520
# 81      82  8.0      579   26   1.0  36   2   16   5.0   70  ...      0.1158
# 82      83  6.0      723   93   1.0  12  39   14   5.0   70  ...      0.1446
#
# ...

# %%
z=df.iloc[:,12:]
z
c=z.sum(axis=1)

# %%
z['final pig']=c
z.to_excel('PIG.xlsx')
