# %%
print('hello guys')

# %%
import pandas as pd

# %%
df=pd.read_excel('water quality.xlsx')
df.head(84)
# Out:
#     Sl no.  longitude  latitude    pH         EC  TDS (m)        TH     Na  \
# 0        1   85.55518  20.20460  6.72   734.3750    470.0  204.8875   42.8
# 1        2   85.52789  20.21843  6.82   790.6250    506.0  269.8750   31.0
# 2        3   85.50241  20.22056  6.80   921.8750    590.0  270.0000   55.0
# 3        4   85.51756  20.22677  7.19   335.9375    215.0  130.0000   16.0
# 4        5   85.51331  20.20680  7.73   971.8750    622.0   60.0000  183.2
# ..     ...        ...       ...   ...        ...      ...       ...    ...
# 78      79   85.21474  20.33129  9.45  1087.5000    696.0  211.6000  116.0
# 79      80   85.22398  20.31859  8.24   731.2500    468.0  334.5000  120.0
# 80      81   85.21126  20.28200  8.22   406.2500    260.0  100.0000   30.0
# 81      82   85.23538  20.27287  8.77   904.6875    579.0  100.0000   25.9
# 82      83   85.26775  20.28239  8.23  1129.6875    723.0  190.0000   92.8
#
# ...

# %%
df=pd.read_excel('water quality.xlsx')
df.head(84)
# Out:
#     Sl no.  longitude  latitude   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  \
# 0        1   85.55518  20.20460  8.0   734      470  205   43   3.0  42  24
# 1        2   85.52789  20.21843  6.8   791      506  270   31   3.0  48  37
# 2        3   85.50241  20.22056  6.8   922      590  270   55   6.0  32  46
# 3        4   85.51756  20.22677  7.2   336      215  130   16   4.0  20  19
# 4        5   85.51331  20.20680  8.5   972      622   60  183   6.0  12   7
# ..     ...        ...       ...  ...   ...      ...  ...  ...   ...  ..  ..
# 78      79   85.21474  20.33129  7.9  1088      696  212  116   6.0  42  26
# 79      80   85.22398  20.31859  6.1   731      468  335  120   3.0  60  45
# 80      81   85.21126  20.28200  8.0   406      260  100   30  17.0  24  10
# 81      82   85.23538  20.27287  8.0   905      579  100   26   1.0  36   2
# 82      83   85.26775  20.28239  6.0  1130      723  190   93   1.0  12  39
#
#     SO4   NO3   Cl     F  HCO3
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x=exmp(df.pH,4,8.5)
df['sub_index_pH']=x

# %%
df.drop(['latitude','longitude','sub_index_HCO3'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.drop(['latitude','longitude','sub_index_HCO3'],axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
#     HCO3  sub_index_HCO3  sub_index_pH
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x=exmp(df.EC,4,1500)
df['sub_index_EC']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
# ...

# %%
df.drop(['sub_index_HCO3'],axis=1,inplace=True)

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
#     HCO3  sub_index_pH  sub_index_EC
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['TDS (m)'], 5, 500)
df['sub_index_TDS (m)'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x=exmp(df.TDS (m),5,500)
df['sub_index_TDS (m)']=x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11096\2291082881.py in ?()
#       1 def exmp(c,w,s):
#       2     relw=w/39
#       3     wqi=relw*(c/s)*100
#       4     return wqi
# ----> 5 x=exmp(df.TDS (m),5,500)
#       6 df['sub_index_TDS (m)']=x
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'TDS'

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x=exmp(df.TH,3,600)
df['sub_index_TH']=x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['Na'], 2, 200)
df['sub_index_Na'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['K'], 1, 12)
df['sub_index_K'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4   NO3   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6   1.0   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  17.0   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  36.0   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6   5.0    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43   0.3  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...   ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40   5.0  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20   2.0   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20   6.0   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16   5.0   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14   5.0   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['Ca'], 2, 75)
df['sub_index_Ca'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...   Cl     F  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...   30  4.00
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...   55  1.40
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...   92  1.20
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...    2  2.30
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...  250  6.40
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...  150  3.80
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...   30  0.70
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...   70  4.30
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...   70  4.30
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...   70  0.01
#
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['Mg'], 2, 50)
df['sub_index_Mg'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...     F  HCO3  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...  4.00   325
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...  1.40   336
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...  1.20   310
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...  2.30   165
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...  6.40   122
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...   ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...  3.80   310
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...  0.70   200
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...  4.30    85
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...  4.30   421
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...  0.01   494
#
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['SO4'], 3, 250)
df['sub_index_SO4'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...  HCO3  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...   325
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...   336
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...   310
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...   165
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...   122
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...   ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...   310
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...   200
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...    85
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...   421
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...   494
#
#     sub_index_pH  sub_index_EC  sub_index_TH  sub_index_TDS (m)  sub_index_Na  \
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['NO3'], 5, 45)
df['sub_index_NO3'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...
#
#     sub_index_pH  sub_index_EC  sub_index_TH  sub_index_TDS (m)  sub_index_Na  \
# 0       9.653092      5.018803      2.628205          12.051282      1.102564
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['Cl'], 2, 250)
df['sub_index_Cl'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...
#
#     sub_index_EC  sub_index_TH  sub_index_TDS (m)  sub_index_Na  sub_index_K  \
# 0       5.018803      2.628205          12.051282      1.102564     0.641026
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['F'], 5, 1.5)
df['sub_index_F'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...
#
#     sub_index_TH  sub_index_TDS (m)  sub_index_Na  sub_index_K  sub_index_Ca  \
# 0       2.628205          12.051282      1.102564     0.641026      2.871795
# ...

# %%
def exmp(c,w,s):
    relw=w/39
    wqi=relw*(c/s)*100
    return wqi
x = exmp(df['HCO3'], 1, 600)
df['sub_index_HCO3'] = x

# %%
df
# Out:
#     Sl no.   pH    EC  TDS (m)   TH   Na     K  Ca  Mg  SO4  ...  \
# 0        1  8.0   734      470  205   43   3.0  42  24    6  ...
# 1        2  6.8   791      506  270   31   3.0  48  37    4  ...
# 2        3  6.8   922      590  270   55   6.0  32  46   17  ...
# 3        4  7.2   336      215  130   16   4.0  20  19    6  ...
# 4        5  8.5   972      622   60  183   6.0  12   7   43  ...
# ..     ...  ...   ...      ...  ...  ...   ...  ..  ..  ...  ...
# 78      79  7.9  1088      696  212  116   6.0  42  26   40  ...
# 79      80  6.1   731      468  335  120   3.0  60  45   20  ...
# 80      81  8.0   406      260  100   30  17.0  24  10   20  ...
# 81      82  8.0   905      579  100   26   1.0  36   2   16  ...
# 82      83  6.0  1130      723  190   93   1.0  12  39   14  ...
#
#     sub_index_TDS (m)  sub_index_Na  sub_index_K  sub_index_Ca  sub_index_Mg  \
# 0           12.051282      1.102564     0.641026      2.871795      2.461538
# ...

# %%
z=df.iloc[:,14:]
c=z.sum(axis=1)

# %%
z['final index']=c
z.to_excel('WQI.xlsx')
